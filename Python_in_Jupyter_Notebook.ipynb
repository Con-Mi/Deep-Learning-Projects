# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Con-Mi/Deep-Learning-Projects/blob/master/Python_in_Jupyter_Notebook.ipynb)

# %% [markdown]
# # Using Python in Jupyter Notebook.

# %% [markdown]
# ## Writing using Markdown markup language.
# ### For example its easy to write equations, similar format with Latex.
# ### The sigmoid equation: $P(x) = \frac{1}{1 + exp(-x)}$
#
# ### You can also add <font style="color:red"> **colorful comments.**</font>
#
# #### You can find more here [Markdown Cheat Sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
# Apart from titles you can also include your comments like the one I have show below.

# %%
# Every cell can be compiled with Ctrl + Enter and prints an output(if any).

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

style.use("ggplot")

rnd_vector1 = np.random.normal(0, 0.25, 200)
rnd_vector2 = np.random.normal(0.2, 0.45, 200)

plt.scatter(rnd_vector1, rnd_vector2)
plt.ylabel("Random Vector 1")
plt.xlabel("Random Vector 2")
plt.title("A simple scatter plot.")
plt.show()

# %% [markdown]
# ## Now we can check what computing resources we have on the collaboratory.

# %% [markdown]
# ### Google Colaboratory runs on Linux, and specifically Ubuntu distribution. Therefore we can use bash commands for profiling.

# %%
# To check how many processes are available, run the following bash command.

# !grep -c ^processor /proc/cpuinfo
# Out:
# 2

# %%
# To check how much RAM memory we have available, run the following.

# !grep MemTotal /proc/meminfo
# Out:
# MemTotal:       13341832 kB

# %%
# Chack platform 
# !uname
# Out:
# Linux

# %%
# Check the list of the CPU details
# !lscpu
# Out:
# Architecture:        x86_64
# CPU op-mode(s):      32-bit, 64-bit
# Byte Order:          Little Endian
# CPU(s):              2
# On-line CPU(s) list: 0,1
# Thread(s) per core:  2
# Core(s) per socket:  1
# Socket(s):           1
# NUMA node(s):        1
# Vendor ID:           GenuineIntel
# CPU family:          6
# Model:               63
# Model name:          Intel(R) Xeon(R) CPU @ 2.30GHz
# Stepping:            0
# CPU MHz:             2300.000
# BogoMIPS:            4600.00
# Hypervisor vendor:   KVM
# Virtualization type: full
# L1d cache:           32K
# L1i cache:           32K
# L2 cache:            256K
# L3 cache:            46080K
# NUMA node0 CPU(s):   0,1
# ...

# %%
# Check the compiler version
# !g++ --version
# Out:
# g++ (Ubuntu 7.2.0-8ubuntu3.2) 7.2.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# To check what is available for the GPU, we need nVidia profiling tools. 
# So we need to install the following. Remember, they will be deleted in 12 hours
# These are optional. You do not need them to use the GPU with Python.
# (Note: This cell will run for a while.)
# !apt-get install nvidia-cuda-dev # You can ignore the outputs.
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   accountsservice acpid activity-log-manager adwaita-icon-theme apg aspell
#   aspell-en at-spi2-core avahi-daemon avahi-utils bbswitch-dkms bind9-host
#   binfmt-support bluez bluez-obexd bsdmainutils ca-certificates-java
#   cheese-common clang-3.8 cracklib-runtime crda cups-pk-helper dbus
#   dbus-user-session dbus-x11 dconf-cli dconf-gsettings-backend dconf-service
#   default-jre default-jre-headless desktop-file-utils dictionaries-common
#   distro-info-data dkms dmsetup dns-root-data dnsmasq-base dosfstools eject
#   emacsen-common enchant evolution-data-server evolution-data-server-common
#   fakeroot file fontconfig fonts-dejavu-extra fuse gcr gdisk geoclue
#   geoclue-ubuntu-geoip geoip-database gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-glib-2.0 gir1.2-gtk-3.0
# ...

# %%
# Same as above.
# !apt-get install nvidia-cuda-toolkit # You can ignore the outputs
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   accountsservice acpid activity-log-manager adwaita-icon-theme apg aspell
#   aspell-en at-spi2-core avahi-daemon avahi-utils bbswitch-dkms bind9-host
#   binfmt-support bluez bluez-obexd bsdmainutils ca-certificates-java
#   cheese-common clang-3.8 cracklib-runtime crda cups-pk-helper dbus
#   dbus-user-session dbus-x11 dconf-cli dconf-gsettings-backend dconf-service
#   default-jre default-jre-headless desktop-file-utils dictionaries-common
#   distro-info-data dkms dmsetup dns-root-data dnsmasq-base dosfstools eject
#   emacsen-common enchant evolution-data-server evolution-data-server-common
#   fakeroot file fontconfig fonts-dejavu-extra fuse gcr gdisk geoclue
#   geoclue-ubuntu-geoip geoip-database gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-glib-2.0 gir1.2-gtk-3.0
# ...

# %%
# Finally run the command to get GPU info.
# !nvidia-smi
# Out:
# Fri Apr 20 09:10:09 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 384.111                Driver Version: 384.111                   |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P8    32W / 149W |      0MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
# To check for the NVIDIA compiler version
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2016 NVIDIA Corporation
# Built on Tue_Jan_10_13:22:03_CST_2017
# Cuda compilation tools, release 8.0, V8.0.61

# %% [markdown]
# ## Uploading your data to the notebook.

# %%
# The following code opens a button to choose data

from google.colab import files

upload = files.upload()
# Out:
#      <input type="file" id="files-96209519-f9fd-4279-aab3-804f0f7348d8" name="files[]" multiple disabled />
#      <output id="result-96209519-f9fd-4279-aab3-804f0f7348d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
# To view what is in the directory you are currently in type the following. Similar to bash commands, just add ! at the front.
# !ls -l
# Out:
# total 28
# drwxr-xr-x 1 root root  4096 Apr 11 21:57 datalab
# -rw-r--r-- 1 root root 24128 Apr 20 01:38 train.csv

# %% [markdown]
# ## Exploring the data that have been uploaded with pandas.

# %%
import pandas as pd
import seaborn as sns # A visualiazation library.

data = pd.read_csv("train.csv")
data.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
correlations = data.corr()
sns.heatmap(correlations)
plt.show()

# %% [markdown]
# ## Using scikit-learn in machine learning projects.

# %%
# In the exapmle, I am going to use one of the easiest dataset. The Iris data.
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

iris_data = load_iris()
X = iris_data.data
y = iris_data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

print("Length of the training set:")
print(len(X_train))

print("Length of the test set:")
print(len(X_test))

clf1 = RandomForestClassifier(n_estimators = 100, criterion = 'entropy', max_depth = 10, n_jobs = 4)
clf1.fit(X_train, y_train)
clf2 = SVC(probability = True)
clf2.fit(X_train, y_train)

print("^^^^^^^^^^^")
print("F1 Score for the Random Forest Classifier:")
print(clf1.score(X_test, y_test))
print("F1 Score for the SVM classifier:")
print(clf2.score(X_test, y_test))
# Out:
# Length of the training set:
# 112
# Length of the test set:
# 38
# ^^^^^^^^^^^
# F1 Score for the Random Forest Classifier:
# 0.9210526315789473
# F1 Score for the SVM classifier:
# 0.9736842105263158

# %%
# Plotting some data using Principal Component Analysis

from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
transform_data = pca.fit_transform(X)

plt.scatter(transform_data[:, 0], transform_data[:, 1], c = y, edgecolor = 'k')
plt.xlabel("First Principal Component.")
plt.ylabel("Second Principal Component.")
plt.title("Reduced Dataset to two dimensions.")
plt.show()

# %%
# Plotting Scatter Plots between the features.

iris_dataframe = pd.DataFrame(iris_data.data)
pd.plotting.scatter_matrix(iris_dataframe)
plt.show()

# %% [markdown]
# ## Using Deep Learning libraries on Google Colab.
# ### Since it offers free GPU resources, we can exploit them with available libraries.
# ### For example, using PyTorch.

# %%
# Code Snippet to download and get the PyTorch Library(Version 3.0).

# http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision
import torch

# %%
# Check for availability of the GPU.

import torch

torch.cuda.is_available()
# Out:
# True

# %%
from torchvision import models

# GPU flag
use_gpu = torch.cuda.is_available()

resnet101 = models.resnet101(pretrained = True) # Loading a 101 layer residual network that is pretrained on ImageNet.
if use_gpu:
  resnet101.cuda() # Here the model is loaded on the GPU.

print(resnet101) # Print the structure of the model.
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /content/.torch/models/resnet101-5d3b4d8f.pth
# 3.6%
# 100.0%
# ResNet(
#   (conv1): Conv2d (3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d (64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d (64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d (64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU(inplace)
# ...

# %%
# Getting some data using available packages.

import torchvision

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)  # This will download the data if they do not exist.
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)  # A loader class to load images.

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# ...
# Files already downloaded and verified
#  deer  frog truck   dog

# %%
# !pip install Pillow==4.0.0  # Install this package for downloading and displaying images
# Out:
# ...
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# The script below is for downloading an image, and the image will be used as input to the network.
# Some preprocessing of the image will be done.

import io
import requests
from PIL import Image
from torchvision import models, transforms
from torch.autograd import Variable
import torchvision.transforms as transforms

LABELS_URL = 'https://s3.amazonaws.com/outcome-blog/imagenet/labels.json'
IMG_URL = 'https://s3.amazonaws.com/outcome-blog/wp-content/uploads/2017/02/25192225/cat.jpg'

normalize = transforms.Normalize(
   mean=[0.485, 0.456, 0.406],
   std=[0.229, 0.224, 0.225]
)                                   # Normalization of an Image
preprocess = transforms.Compose([
   transforms.Resize(256),
   transforms.CenterCrop(224),
   transforms.ToTensor(),
   normalize
])                                  # A preprocess function to apply on an image


response = requests.get(IMG_URL)
img_pil = Image.open(io.BytesIO(response.content))

img_pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=560x372 at 0x7FEBF43E55C0>

# %%
img_tensor = preprocess(img_pil) # Preprocess the image
img_tensor.unsqueeze_(0)  # This adds a batch dimension to the image. Meaning that is just one image. Required if you use PyTorch

img_variable = Variable(img_tensor).cuda() # Converts the image into a Variable for automatic differentiation. Then loads it on the GPU.
fc_out = resnet101(img_variable) # Forward run of the network.

# %%
labels = {int(key):value for (key, value)
          in requests.get(LABELS_URL).json().items()}
print(labels) # Available labels for the ImageNet
# Out:
# {0: 'tench, Tinca tinca', 1: 'goldfish, Carassius auratus', 2: 'great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias', 3: 'tiger shark, Galeocerdo cuvieri', 4: 'hammerhead, hammerhead shark', 5: 'electric ray, crampfish, numbfish, torpedo', 6: 'stingray', 7: 'cock', 8: 'hen', 9: 'ostrich, Struthio camelus', 10: 'brambling, Fringilla montifringilla', 11: 'goldfinch, Carduelis carduelis', 12: 'house finch, linnet, Carpodacus mexicanus', 13: 'junco, snowbird', 14: 'indigo bunting, indigo finch, indigo bird, Passerina cyanea', 15: 'robin, American robin, Turdus migratorius', 16: 'bulbul', 17: 'jay', 18: 'magpie', 19: 'chickadee', 20: 'water ouzel, dipper', 21: 'kite', 22: 'bald eagle, American eagle, Haliaeetus leucocephalus', 23: 'vulture', 24: 'great grey owl, great gray owl, Strix nebulosa', 25: 'European fire salamander, Salamandra salamandra', 26: 'common newt, Triturus vulgaris', 27: 'eft', 28: 'spotted salamander, Ambystoma maculatum', 29: 'axolotl, 
# ...

# %%
fc_out = fc_out.cpu() # Results returned on the CPU
print(labels[fc_out.data.numpy().argmax()]) # Highest result from the network
# Out:
# bucket, pail

# %%
# You can also load TensorFLow or Keras (no need to download it.)

import tensorflow as tf
import keras
